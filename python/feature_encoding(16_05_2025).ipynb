# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv("/content/practice_data.csv")

df.head()
# Out:
#    EmployeeID  gender  ... Sales Revenue Generated  churned
# 0           1    Male  ...                   51638       No
# 1           2  Female  ...                   97797      Yes
# 2           3    Male  ...                   95341       No
# 3           4    Male  ...                   91806       No
# 4           5  Female  ...                   64247      Yes
#
# [5 rows x 11 columns]

# %%
label_encoder = LabelEncoder()
df['gender']= label_encoder.fit_transform(df['gender'])

# df['gender'].unique()
print(df['gender'].head())
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: gender, dtype: int64
